# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt
from pathlib import Path
import pandas as pd

# %%
def get_stat_str(v, ids):
    df = pd.DataFrame({"i": ids, "v": v})
    mean_values = df.groupby('i')['v'].mean().values
    
    mean_val = np.mean(mean_values)
    std_val = np.std(mean_values)
    med_val = np.median(mean_values)
    
    simple_mean = np.mean(v)
    simple_median = np.median(v)
    return f"{mean_val:.3f} +- {std_val:.3f} (median: {med_val:.3f})    ({simple_mean:.2f}, {simple_median:.2f})"

# %%
def get_metrics(d):
    length = d['length']
    if "diversity" in d:
        diversity = d['diversity']
    ring_cond = d['num_rings'] == d['num_valid_rings']
    is_tree = d['num_rings'] == 0
    bond_cond = d['num_bonds'] == d['num_valid_bonds']
    angle_cond = d['num_angles'] == d['num_valid_angles']
    clash_cond = d['num_noncov'] == d['num_valid_noncov']
    qed = d['qed']
    if 'docking_score' in d:
        docking_score = d['docking_score']
    if 'docking_score_better_than_ref' in d:
        better_docking = d['docking_score_better_than_ref']
    lipinski = d['lipinski']
    tansim = d['tansim']
    sa = d['sa']
    

    bust_pass = ring_cond & bond_cond & bond_cond & angle_cond & clash_cond
    
    result = {
        "length": length,
        "ring_cond": ring_cond,
        "is_tree": is_tree,
        "bond_cond": bond_cond,
        "angle_cond": angle_cond,
        "clash_cond": clash_cond,
        "qed": qed,
        "lipinski": lipinski,
        "tansim": tansim,
        "sa": sa,
    }
    
    if "diversity" in d:
        result.update({
            "diversity": diversity
        })
    
    result.update({
        "bust_pass": bust_pass
    })
    
    if "docking_score" in d:
        result.update({
            "docking_score": docking_score
        })
    
    if 'docking_score_better_than_ref' in d:
        result.update({
            "better_docking": better_docking
        })
    
    return result

def print_stats(d, only_core=False):
    metrics = get_metrics(d)
    
    target_ids = d["target_id"]
    unique_target_ids = np.unique(target_ids)
    print("# of targets:", len(unique_target_ids))
    print("average_n:", len(target_ids) / len(unique_target_ids))
    for key, vals in metrics.items():
        if only_core:
            if not key in ["length", "diversity", "bust_pass", "ring_cond", "bond_cond", "angle_cond", "clash_cond", "qed", "lipinski", "sa", "docking_score", "better_docking"]:
                continue
        if key in ["ring_cond", "bond_cond", "angle_cond", "clash_cond", "bust_pass"]:
            key = f"{key}_fail"
            vals = 1 - vals
        print(f"{key}:", get_stat_str(vals, target_ids))

# %%
info = {
    "ligan": "ligan",
    "ar": "ar",
    "graphbp": "graphbp",
    "flag:": "flag",
    "targetdiff": "targetdiff",
    "pocket2mol": "pocket2mol",
    "p2mrl": "p2mrl",
    "ref": "ref",
}

def load_metrics(file):
    if file.exists():
        with open(file, "rb") as f:
            return pickle.load(f)
    else:
        return None
    
test_metrics = {}
for key, val in info.items():
    file = Path(f"test_cache/test_{val}_outputs/metrics.pkl")
    if file is None:
        continue
    metrics = load_metrics(file)
    if metrics is not None:
        test_metrics[key] = metrics

# %%
print("<< test Results >>")
for title, metrics in test_metrics.items():
    print("<", title, ">")
    print_stats(metrics, only_core=True)
    print("----------------------------------------")
# Out:
# << test Results >>
# < ligan >
# # of targets: 100
# average_n: 96.9
# length: 19.976 +- 8.190 (median: 20.201)    (19.93, 20.00)
# ring_cond_fail: 0.140 +- 0.183 (median: 0.033)    (0.14, 0.00)
# bond_cond_fail: 0.969 +- 0.089 (median: 1.000)    (0.97, 1.00)
# angle_cond_fail: 0.930 +- 0.137 (median: 1.000)    (0.93, 1.00)
# clash_cond_fail: 0.564 +- 0.317 (median: 0.624)    (0.56, 1.00)
# qed: 0.391 +- 0.192 (median: 0.421)    (0.39, 0.39)
# lipinski: 4.168 +- 1.233 (median: 4.893)    (4.16, 5.00)
# sa: 0.591 +- 0.123 (median: 0.580)    (0.59, 0.57)
# diversity: 0.345 +- 0.114 (median: 0.334)    (0.34, 0.33)
# bust_pass_fail: 0.985 +- 0.057 (median: 1.000)    (0.98, 1.00)
# docking_score: -6.359 +- 1.564 (median: -6.453)    (-6.36, -6.40)
# better_docking: 0.131 +- 0.188 (median: 0.051)    (0.13, 0.00)
# ----------------------------------------
# < ar >
# # of targets: 97
# average_n: 89.17525773195877
# length: 17.558 +- 6.001 (median: 16.820)    (17.23, 16.00)
# ring_cond_fail: 0.330 +- 0.309 (median: 0.221)    (0.32, 0.00)
# bond_cond_fail: 0.063 +- 0.070 (median: 0.041)    (0.06, 0.00)
# angle_cond_fail: 0.185 +- 0.179 (median: 0.111)    (0.17, 0.00)
# clash_cond_fail: 0.201 +- 0.191 (median: 0.140)    (0.19, 0.00)
# qed: 0.507 +- 0.118 (median: 0.501)    (0.51, 0.50)
# lipinski: 4.761 +- 0.308 (median: 4.918)    (4.76, 5.00)
# sa: 0.641 +- 0.092 (median: 0.635)    (0.65, 0.64)
# diversity: 0.299 +- 0.121 (median: 0.291)    (0.30, 0.28)
# bust_pass_fail: 0.531 +- 0.296 (median: 0.540)    (0.52, 1.00)
# docking_score: -6.600 +- 1.538 (median: -6.624)    (-6.57, -6.40)
# better_docking: 0.296 +- 0.312 (median: 0.155)    (0.29, 0.00)
# ----------------------------------------
# < graphbp >
# # of targets: 100
# average_n: 87.14
# length: 23.898 +- 1.226 (median: 23.933)    (23.89, 21.00)
# ring_cond_fail: 0.009 +- 0.010 (median: 0.011)    (0.01, 0.00)
# bond_cond_fail: 0.946 +- 0.023 (median: 0.951)    (0.95, 1.00)
# angle_cond_fail: 0.961 +- 0.022 (median: 0.966)    (0.96, 1.00)
# clash_cond_fail: 0.770 +- 0.044 (median: 0.771)    (0.77, 1.00)
# qed: 0.431 +- 0.021 (median: 0.431)    (0.43, 0.46)
# lipinski: 4.533 +- 0.064 (median: 4.538)    (4.53, 5.00)
# sa: 0.481 +- 0.016 (median: 0.482)    (0.48, 0.48)
# diversity: 0.216 +- 0.013 (median: 0.217)    (0.22, 0.22)
# bust_pass_fail: 0.980 +- 0.015 (median: 0.983)    (0.98, 1.00)
# docking_score: -5.133 +- 0.586 (median: -5.196)    (-5.13, -5.00)
# better_docking: 0.149 +- 0.231 (median: 0.048)    (0.15, 0.00)
# ----------------------------------------
# < flag: >
# # of targets: 98
# average_n: 80.3265306122449
# length: 16.708 +- 1.539 (median: 16.387)    (16.73, 16.00)
# ring_cond_fail: 0.022 +- 0.026 (median: 0.013)    (0.02, 0.00)
# bond_cond_fail: 0.055 +- 0.039 (median: 0.048)    (0.05, 0.00)
# angle_cond_fail: 0.313 +- 0.080 (median: 0.304)    (0.32, 0.00)
# clash_cond_fail: 0.178 +- 0.081 (median: 0.186)    (0.18, 0.00)
# qed: 0.608 +- 0.025 (median: 0.610)    (0.61, 0.63)
# lipinski: 4.986 +- 0.015 (median: 4.988)    (4.99, 5.00)
# sa: 0.648 +- 0.044 (median: 0.653)    (0.65, 0.64)
# diversity: 0.226 +- 0.068 (median: 0.203)    (0.23, 0.21)
# bust_pass_fail: 0.344 +- 0.074 (median: 0.342)    (0.35, 0.00)
# docking_score: -6.020 +- 0.739 (median: -5.989)    (-6.02, -6.00)
# better_docking: 0.238 +- 0.312 (median: 0.078)    (0.23, 0.00)
# ----------------------------------------
# < targetdiff >
# # of targets: 100
# average_n: 90.08
# length: 24.433 +- 6.784 (median: 24.643)    (24.23, 24.00)
# ring_cond_fail: 0.069 +- 0.048 (median: 0.061)    (0.07, 0.00)
# bond_cond_fail: 0.052 +- 0.040 (median: 0.041)    (0.05, 0.00)
# angle_cond_fail: 0.383 +- 0.148 (median: 0.398)    (0.38, 0.00)
# clash_cond_fail: 0.187 +- 0.078 (median: 0.187)    (0.18, 0.00)
# qed: 0.478 +- 0.110 (median: 0.485)    (0.48, 0.48)
# lipinski: 4.572 +- 0.410 (median: 4.734)    (4.59, 5.00)
# sa: 0.583 +- 0.066 (median: 0.572)    (0.58, 0.58)
# diversity: 0.283 +- 0.090 (median: 0.286)    (0.28, 0.29)
# bust_pass_fail: 0.510 +- 0.162 (median: 0.534)    (0.51, 1.00)
# docking_score: -7.215 +- 1.398 (median: -7.371)    (-7.21, -7.30)
# better_docking: 0.467 +- 0.328 (median: 0.399)    (0.48, 0.00)
# ----------------------------------------
# < pocket2mol >
# # of targets: 100
# average_n: 113.82
# length: 18.121 +- 7.714 (median: 16.886)    (17.68, 15.00)
# ring_cond_fail: 0.215 +- 0.165 (median: 0.183)    (0.21, 0.00)
# bond_cond_fail: 0.203 +- 0.139 (median: 0.161)    (0.20, 0.00)
# angle_cond_fail: 0.040 +- 0.057 (median: 0.019)    (0.04, 0.00)
# clash_cond_fail: 0.044 +- 0.082 (median: 0.019)    (0.04, 0.00)
# qed: 0.573 +- 0.096 (median: 0.590)    (0.57, 0.58)
# lipinski: 4.925 +- 0.167 (median: 4.997)    (4.92, 5.00)
# sa: 0.744 +- 0.080 (median: 0.756)    (0.75, 0.76)
# diversity: 0.264 +- 0.149 (median: 0.233)    (0.26, 0.22)
# bust_pass_fail: 0.380 +- 0.194 (median: 0.353)    (0.37, 0.00)
# docking_score: -7.278 +- 2.113 (median: -6.944)    (-7.14, -6.70)
# better_docking: 0.462 +- 0.323 (median: 0.444)    (0.47, 0.00)
# ----------------------------------------
# < p2mrl >
# # of targets: 100
# average_n: 99.53
# length: 18.274 +- 6.302 (median: 18.167)    (18.27, 17.00)
# ring_cond_fail: 0.071 +- 0.071 (median: 0.056)    (0.07, 0.00)
# bond_cond_fail: 0.170 +- 0.122 (median: 0.141)    (0.17, 0.00)
# angle_cond_fail: 0.033 +- 0.036 (median: 0.020)    (0.03, 0.00)
# clash_cond_fail: 0.017 +- 0.020 (median: 0.010)    (0.02, 0.00)
# qed: 0.644 +- 0.098 (median: 0.673)    (0.64, 0.66)
# lipinski: 4.970 +- 0.108 (median: 5.000)    (4.97, 5.00)
# sa: 0.836 +- 0.048 (median: 0.836)    (0.84, 0.86)
# diversity: 0.230 +- 0.051 (median: 0.226)    (0.23, 0.23)
# bust_pass_fail: 0.238 +- 0.151 (median: 0.205)    (0.24, 0.00)
# docking_score: -7.398 +- 1.865 (median: -7.345)    (-7.40, -7.20)
# better_docking: 0.507 +- 0.328 (median: 0.586)    (0.51, 1.00)
# ----------------------------------------
# < ref >
# # of targets: 100
# average_n: 1.0
# length: 22.750 +- 9.908 (median: 21.500)    (22.75, 21.50)
# ring_cond_fail: 0.000 +- 0.000 (median: 0.000)    (0.00, 0.00)
# bond_cond_fail: 0.020 +- 0.140 (median: 0.000)    (0.02, 0.00)
# angle_cond_fail: 0.000 +- 0.000 (median: 0.000)    (0.00, 0.00)
# clash_cond_fail: 0.040 +- 0.196 (median: 0.000)    (0.04, 0.00)
# qed: 0.476 +- 0.205 (median: 0.468)    (0.48, 0.47)
# lipinski: 4.340 +- 1.142 (median: 5.000)    (4.34, 5.00)
# sa: 0.728 +- 0.139 (median: 0.740)    (0.73, 0.74)
# diversity: nan +- nan (median: nan)    (nan, nan)
# bust_pass_fail: 0.060 +- 0.237 (median: 0.000)    (0.06, 0.00)
# docking_score: -7.383 +- 2.157 (median: -7.350)    (-7.38, -7.35)
# better_docking: 0.000 +- 0.000 (median: 0.000)    (0.00, 0.00)
# ----------------------------------------
